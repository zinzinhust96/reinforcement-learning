# %%
# %matplotlib inline

import gym
import itertools
import matplotlib
import numpy as np
import sys
import sklearn.pipeline
import sklearn.preprocessing

if "../" not in sys.path:
  sys.path.append("../") 

from lib import plotting
from sklearn.linear_model import SGDRegressor
from sklearn.kernel_approximation import RBFSampler

matplotlib.style.use('ggplot')

# %%
env = gym.envs.make("MountainCar-v0")

# %%
print('action_space: ', env.action_space)
print('observation_space: ', env.observation_space)
# Out:
# action_space:  Discrete(3)
# observation_space:  Box(2,)

# %%
# Feature Preprocessing: Normalize to zero mean and unit variance
# We use a few samples from the observation space to do this
observation_examples = np.array([env.observation_space.sample() for x in range(10000)])
scaler = sklearn.preprocessing.StandardScaler()
scaler.fit(observation_examples)

# Used to convert a state to a featurizes represenation.
# We use RBF kernels with different variances to cover different parts of the space
featurizer = sklearn.pipeline.FeatureUnion([
        ("rbf1", RBFSampler(gamma=5.0, n_components=100)),
        ("rbf2", RBFSampler(gamma=2.0, n_components=100)),
        ("rbf3", RBFSampler(gamma=1.0, n_components=100)),
        ("rbf4", RBFSampler(gamma=0.5, n_components=100))
        ])
featurizer.fit(scaler.transform(observation_examples))
# Out:
# FeatureUnion(transformer_list=[('rbf1', RBFSampler(gamma=5.0)),
#                                ('rbf2', RBFSampler(gamma=2.0)),
#                                ('rbf3', RBFSampler()),
#                                ('rbf4', RBFSampler(gamma=0.5))])

# %%
state = env.reset()
print(state, state.shape)
# Out:
# [-0.50067854  0.        ] (2,)

# %%
class Estimator():
    """
    Value Function approximator. 
    """
    
    def __init__(self):
        # We create a separate model for each action in the environment's
        # action space. Alternatively we could somehow encode the action
        # into the features, but this way it's easier to code up.
        self.models = []
        for _ in range(env.action_space.n):
            model = SGDRegressor(learning_rate="constant")
            # We need to call partial_fit once to initialize the model
            # or we get a NotFittedError when trying to make a prediction
            # This is quite hacky.
            model.partial_fit([self.featurize_state(env.reset())], [0])
            self.models.append(model)
    
    def featurize_state(self, state):
        """
        Returns the featurized representation for a state.
        """
        scaled = scaler.transform([state])
        featurized = featurizer.transform(scaled)
        return featurized[0]
    
    def predict(self, s, a=None):
        """
        Makes value function predictions.
        
        Args:
            s: state to make a prediction for
            a: (Optional) action to make a prediction for
            
        Returns
            If an action a is given this returns a single number as the prediction.
            If no action is given this returns a vector or predictions for all actions
            in the environment where pred[i] is the prediction for action i.
            
        """
        features = self.featurize_state(s)
        if not a:
            return np.array([m.predict([features])[0] for m in self.models])
        else:
            return self.models[a].predict([features])[0]
    
    def update(self, s, a, y):
        """
        Updates the estimator parameters for a given state and action towards
        the target y.
        """
        features = self.featurize_state(s)
        self.models[a].partial_fit([features], [y])

# %%
def make_epsilon_greedy_policy(estimator, epsilon, nA):
    """
    Creates an epsilon-greedy policy based on a given Q-function approximator and epsilon.
    
    Args:
        estimator: An estimator that returns q values for a given state
        epsilon: The probability to select a random action . float between 0 and 1.
        nA: Number of actions in the environment.
    
    Returns:
        A function that takes the observation as an argument and returns
        the probabilities for each action in the form of a numpy array of length nA.
    
    """
    def policy_fn(observation):
        A = np.ones(nA, dtype=float) * epsilon / nA
        q_values = estimator.predict(observation)
        best_action = np.argmax(q_values)
        A[best_action] += (1.0 - epsilon)
        return A
    return policy_fn

# %%
def q_learning(env, estimator, num_episodes, discount_factor=1.0, epsilon=0.1, epsilon_decay=1.0):
    """
    Q-Learning algorithm for fff-policy TD control using Function Approximation.
    Finds the optimal greedy policy while following an epsilon-greedy policy.
    
    Args:
        env: OpenAI environment.
        estimator: Action-Value function estimator
        num_episodes: Number of episodes to run for.
        discount_factor: Gamma discount factor.
        epsilon: Chance the sample a random action. Float betwen 0 and 1.
        epsilon_decay: Each episode, epsilon is decayed by this factor
    
    Returns:
        An EpisodeStats object with two numpy arrays for episode_lengths and episode_rewards.
    """

    # Keeps track of useful statistics
    stats = plotting.EpisodeStats(
        episode_lengths=np.zeros(num_episodes),
        episode_rewards=np.zeros(num_episodes))    
    
    for i_episode in range(num_episodes):
        
        # The policy we're following
        policy = make_epsilon_greedy_policy(
            estimator, epsilon * epsilon_decay**i_episode, env.action_space.n)
        
        # Print out which episode we're on, useful for debugging.
        # Also print reward for last episode
        last_reward = stats.episode_rewards[i_episode - 1]
        sys.stdout.flush()
        
        # Reset the environment and pick the first action
        state = env.reset()
        print('state shape: ', state.shape)
        
        # Only used for SARSA, not Q-Learning
        next_action = None
        
        # One step in the environment
        for t in itertools.count():
                        
            # Choose an action to take
            # If we're using SARSA we already decided in the previous step
            if next_action is None:
                # Q-Learning
                action_probs = policy(state)
                action = np.random.choice(np.arange(len(action_probs)), p=action_probs)
            else:
                # SARSA
                action = next_action
            
            # Take a step
            next_state, reward, done, _ = env.step(action)
    
            # Update statistics
            stats.episode_rewards[i_episode] += reward
            stats.episode_lengths[i_episode] = t
            
            # TD Update
            q_values_next = estimator.predict(next_state)
            
            # Use this code for Q-Learning
            # Q-Value TD Target
            td_target = reward + discount_factor * np.max(q_values_next)
            
            # Use this code for SARSA TD Target for on policy-training:
            # next_action_probs = policy(next_state)
            # next_action = np.random.choice(np.arange(len(next_action_probs)), p=next_action_probs)             
            # td_target = reward + discount_factor * q_values_next[next_action]
            
            # Update the function approximator using our target
            estimator.update(state, action, td_target)
            
            print("\rStep {} @ Episode {}/{} ({})".format(t, i_episode + 1, num_episodes, last_reward), end="")
                
            if done:
                break
                
            state = next_state
    
    return stats

# %%
estimator = Estimator()

# %%
# Note: For the Mountain Car we don't actually need an epsilon > 0.0
# because our initial estimate for all states is too "optimistic" which leads
# to the exploration of all states.
stats = q_learning(env, estimator, 100, epsilon=0.0)
# Out:
# state shape:  (2,)
# Step 199 @ Episode 1/100 (0.0)state shape:  (2,)
# Step 199 @ Episode 2/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 3/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 4/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 5/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 6/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 7/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 8/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 9/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 10/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 11/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 12/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 13/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 14/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 15/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 16/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 17/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 18/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 19/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 20/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 21/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 22/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 23/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 24/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 25/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 26/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 27/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 28/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 29/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 30/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 31/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 32/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 33/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 34/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 35/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 36/100 (-200.0)state shape: (2,)
# Step 178 @ Episode 37/100 (-200.0)state shape: (2,)
# Step 199 @ Episode 38/100 (-179.0)state shape:  (2,)
# Step 199 @ Episode 39/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 40/100 (-200.0)state shape:  (2,)
# Step 173 @ Episode 41/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 42/100 (-174.0)state shape:  (2,)
# Step 199 @ Episode 43/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 44/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 45/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 46/100 (-200.0)state shape:  (2,)
# Step 164 @ Episode 47/100 (-200.0)state shape:  (2,)
# Step 162 @ Episode 48/100 (-165.0)state shape:  (2,)
# Step 193 @ Episode 49/100 (-163.0)state shape:  (2,)
# Step 192 @ Episode 50/100 (-194.0)state shape:  (2,)
# Step 199 @ Episode 51/100 (-193.0)state shape:  (2,)
# Step 170 @ Episode 52/100 (-200.0)state shape:  (2,)
# Step 163 @ Episode 53/100 (-171.0)state shape:  (2,)
# Step 158 @ Episode 54/100 (-164.0)state shape:  (2,)
# Step 167 @ Episode 55/100 (-159.0)state shape:  (2,)
# Step 195 @ Episode 56/100 (-168.0)state shape:  (2,)
# Step 160 @ Episode 57/100 (-196.0)state shape:  (2,)
# Step 199 @ Episode 58/100 (-161.0)state shape:  (2,)
# Step 177 @ Episode 59/100 (-200.0)state shape:  (2,)
# Step 118 @ Episode 60/100 (-178.0)state shape:  (2,)
# Step 199 @ Episode 61/100 (-119.0)state shape:  (2,)
# Step 162 @ Episode 62/100 (-200.0)state shape:  (2,)
# Step 199 @ Episode 63/100 (-163.0)state shape:  (2,)
# Step 167 @ Episode 64/100 (-200.0)state shape:  (2,)
# Step 187 @ Episode 65/100 (-168.0)state shape:  (2,)
# Step 168 @ Episode 66/100 (-188.0)state shape:  (2,)
# Step 162 @ Episode 67/100 (-169.0)state shape:  (2,)
# Step 174 @ Episode 68/100 (-163.0)state shape:  (2,)
# Step 156 @ Episode 69/100 (-175.0)state shape:  (2,)
# Step 156 @ Episode 70/100 (-157.0)state shape:  (2,)
# Step 121 @ Episode 71/100 (-157.0)state shape:  (2,)
# Step 119 @ Episode 72/100 (-122.0)state shape:  (2,)
# Step 160 @ Episode 73/100 (-120.0)state shape:  (2,)
# Step 166 @ Episode 74/100 (-161.0)state shape:  (2,)
# Step 118 @ Episode 75/100 (-167.0)state shape:  (2,)
# Step 158 @ Episode 76/100 (-119.0)state shape:  (2,)
# Step 199 @ Episode 77/100 (-159.0)state shape:  (2,)
# Step 192 @ Episode 78/100 (-200.0)state shape:  (2,)
# Step 112 @ Episode 79/100 (-193.0)state shape:  (2,)
# Step 112 @ Episode 80/100 (-113.0)state shape:  (2,)
# Step 165 @ Episode 81/100 (-113.0)state shape:  (2,)
# Step 95 @ Episode 82/100 (-166.0)state shape:  (2,)
# Step 165 @ Episode 83/100 (-96.0)state shape:  (2,)
# Step 119 @ Episode 84/100 (-166.0)state shape:  (2,)
# Step 110 @ Episode 85/100 (-120.0)state shape:  (2,)
# Step 113 @ Episode 86/100 (-111.0)state shape:  (2,)
# Step 115 @ Episode 87/100 (-114.0)state shape:  (2,)
# Step 163 @ Episode 88/100 (-116.0)state shape:  (2,)
# Step 176 @ Episode 89/100 (-164.0)state shape:  (2,)
# Step 116 @ Episode 90/100 (-177.0)state shape:  (2,)
# Step 172 @ Episode 91/100 (-117.0)state shape:  (2,)
# Step 117 @ Episode 92/100 (-173.0)state shape:  (2,)
# Step 111 @ Episode 93/100 (-118.0)state shape:  (2,)
# Step 114 @ Episode 94/100 (-112.0)state shape:  (2,)
# Step 112 @ Episode 95/100 (-115.0)state shape:  (2,)
# Step 110 @ Episode 96/100 (-113.0)state shape:  (2,)
# Step 115 @ Episode 97/100 (-111.0)state shape:  (2,)
# Step 122 @ Episode 98/100 (-116.0)state shape:  (2,)
# Step 153 @ Episode 99/100 (-123.0)state shape:  (2,)
# Step 115 @ Episode 100/100 (-154.0)

# %%
plotting.plot_cost_to_go_mountain_car(env, estimator)
plotting.plot_episode_stats(stats, smoothing_window=25)
# Out:
# (<Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>,
#  <Figure size 720x360 with 1 Axes>)

# %%
observation = env.reset()
for t in range(200):
    env.render()
    best_action = np.argmax(estimator.predict(observation))
    observation, reward, done, info = env.step(best_action)
    if done:
        print("Episode finished after {} timesteps".format(t+1))
        break
env.close()
# Out:
# Episode finished after 132 timesteps
