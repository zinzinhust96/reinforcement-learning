# %%
# %matplotlib inline

import gym
import numpy as np
from matplotlib import pyplot as plt

# %%
env = gym.envs.make("MountainCar-v0")

# %%
print('action_space: ', env.action_space)
print('observation_space: ', env.observation_space)
print(env.observation_space.low[0], env.observation_space.high[0])
print(env.observation_space.low[1], env.observation_space.high[1])
# Out:
# action_space:  Discrete(3)
# observation_space:  Box(2,)
# -1.2 0.6
# -0.07 0.07

# %%
state = env.reset()
print(state, state.shape)
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

[env.step(0) for x in range(10000)]
next_state, reward, done, _ = env.step(0)
print(next_state, next_state.shape)
plt.figure()
plt.imshow(env.render(mode='rgb_array'))

env.close()
# Out:
# [-0.48798642  0.        ] (2,)
# [-0.64212252  0.01467785] (2,)

# %%
for i_episode in range(5):
    observation = env.reset()
    for t in range(1000):
        env.render()
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after {} timesteps".format(t+1))
            break
env.close()
# Out:
# Episode finished after 200 timesteps
# Episode finished after 200 timesteps
# Episode finished after 200 timesteps
# Episode finished after 200 timesteps
# Episode finished after 200 timesteps
